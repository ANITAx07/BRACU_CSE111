# %%
 #1
class Patient:
  def __init__(self,name,age,weight,height):
    self.name=name
    self.age=age
    self.weight=weight
    self.height=height

  def printDetails(self):
    print(f'Name:{self.name}\nAge:{self.age}\nWeight:{self.weight}\nHeight:{self.height}\nBMI:{(self.weight)/(self.height/100)**2}')

p1 = Patient("A", 55, 63.0, 158.0)
p1.printDetails()
print("====================")
p2 = Patient("B", 53, 61.0, 149.0)
p2.printDetails()
# Out:
# Name:A
# Age:55
# Weight:63.0
# Height:158.0
# BMI:25.236340330075304
# ...
# Name:B
# Age:53
# Weight:61.0
# Height:149.0
# BMI:27.476239809017613

# %%
#2
class Shape:
  import math
  def __init__(self,name,a,b):
    self.name=name
    self.a=a
    self.b=b
  def area(self):
    if self.name=="Triangle":
      print(f'Area:{0.5*self.a*self.b}')
    elif self.name=="Square" :
      print(f'Area:{self.a*self.b}')
    elif self.name=="Rhombus" :
      print(f'Area:{0.5*self.a*self.b}')
    elif self.name=="Rectangle" :
      print(f'Area:{self.a*self.b}')
    elif self.name=="Rectangle" :
      print(f'Area:{self.a*self.b}')
    else:
      print("Area:shape unknown")


triangle = Shape("Triangle",10,25)
triangle.area()
print("==========================")
square = Shape("Square",10,10)
square.area()
print("==========================")
rhombus = Shape("Rhombus",18,25)
rhombus.area()
print("==========================")
rectangle = Shape("Rectangle",15,30)
rectangle.area()
print("==========================")
trapezium = Shape("Trapezium",15,30)
trapezium.area()
# Out:
# Area:125.0
# ...
# Area:100
# ...
# Area:225.0
# ...
# Area:450
# ...
# Area:shape unknown

# %%
#3
class  Calculator:
  # def __init__(self):
  #   pass
  #   print('Calculator is ready!')
  def calculate(self,n1,n2,op):
    self.n1=n1
    self.n2=n2
    self.op=op

    if self.op =='+':
      v=self.n1+self.n2
      return v
    elif self.op == '-':
      v=self.n1-self.n2
      return v
    elif self.op == '*':
      v=self.n1*self.n2
      return v
    elif self.op == '/':
      v=self.n1/self.n2
      return v

  def showCalculation(self):
    if self.op =='+':
      print(self.n1,'+',self.n2,'=',)
    elif self.op == '-':
      print(self.n1,'-',self.n2,'=',)
    elif self.op == '*':
      print(self.n1,'*',self.n2,'=',)
    elif self.op == '/':
      print(self.n1,'/',self.n2,'=',)
print("Calculator is ready!")
c1 = Calculator()
print("==================")
val = c1.calculate(10, 20, '+')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 10, '-')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 5, '*')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 16, '/')
print("Returned value:", val)
c1.showCalculation()
# Out:
# Calculator is ready!
# ...
# Returned value: 30
# 10 + 20 =
# ...
# Returned value: 20
# 30 - 10 =
# ...
# Returned value: 100
# 20 * 5 =
# ...
# Returned value: 6.25
# 100 / 16 =

# %%
#4
class Programmer:
  def __init__(self,name,lan,exp):
    self.name=name
    self.lan=lan
    self.exp=exp
    print('Horray! A new programmer is born')
  def printDetails(self):
    print(f'name={self.name}\nlanguage={self.lan}\nexperience={self.exp}')
  def addExp(self,add):
     print(f'Updating experience of{self.name}')
     self.exp+=add


p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()#method1
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)#method2
p3.printDetails()
# Out:
# Horray! A new programmer is born
# name=Ethen Hunt
# language=Java
# experience=10
# --------------------------
# Horray! A new programmer is born
# name=James Bond
# language=C++
# experience=7
# --------------------------
# Horray! A new programmer is born
# name=Jon Snow
# language=Python
# experience=4
# Updating experience ofJon Snow
# name=Jon Snow
# language=Python
# experience=9

# %%
#practise
class Programmer:
  def __init__(self,name,lang,exp):
    self.name=name
    self.lang=lang
    self.exp=exp
    print('Horray! A new programmer is born')
  def printDetails(self):
    print(f'name={self.name}\nlanguage={self.lang}\nexperience={self.exp}')
  def addExp(self,add):
     print(f'Updating experience of{self.name}')
     self.exp+=add
  def addlang(self,lng):
    self.lang=self.lang+','+lng

p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
p1.addlang('C++')
# Out:
# Horray! A new programmer is born
# name=Ethen Hunt
# language=Java
# experience=10

# %%
#prac
class Programmer:
  def __init__(self,name,lang,exp):
    self.name=name
    self.lang=[]
    self.lang.append(lang)
    self.exp=exp
    print('Horray! A new programmer is born')
  def printDetails(self):
    print(f'name={self.name}\nlanguage={self.lang}\nexperience={self.exp}')
  def addExp(self,add):
     print(f'Updating experience of{self.name}')
     self.exp+=add
  def addlang(self,lng):
    self.lang.append(lng)

p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
p1.addlang('C++')
# Out:
# Horray! A new programmer is born
# name=Ethen Hunt
# language=['Java']
# experience=10

# %%
#prac
class Programmer:
  def __init__(self,name,lang,exp):
    self.name=name
    self.lang=[]
    self.lang.append(lang)
    self.exp=exp
    print('Horray! A new programmer is born')

  def printDetails(self):
    print(f'name={self.name}\nlanguage={self.lang}\nexperience={self.exp}')

  def addExp(self,add):
     self.exp+=add
     return f'Updating experience of{self.name}'  #return method


  def addlang(self,lng):
    self.lang.append(lng)

p1 = Programmer("Ethen Hunt", "Java", 10)
print(p1.printDetails())
p1.addlang('C++')
# Out:
# Horray! A new programmer is born
# name=Ethen Hunt
# language=['Java']
# experience=10
# None

# %%
#5
class UberEats:
  def __init__(self,name,phone,adress):
    self.d={}
    self.name=name
    self.phone=phone
    self.adress=adress
    print(f'{self.name} welcome to uber eats')

  def add_items(self,*arg):
     self.item1,self.item2,self.price1,self.price2=arg
     self.d[self.item1]=self.price1
     self.d[self.item2]=self.price2

  def print_order_detail(self):
    print(f'user details:{self.name},Phone:{self.phone},Adress:{self.adress}')
    print(f'orders:{self.d}')
    return f'Total paid:{self.price1+self.price2}'


order1 = UberEats("Shakib", "01719658xxx", "Mohakhali")
print("=========================")
order1.add_items("Burger", "Coca Cola", 220, 50)
print("=========================")
print(order1.print_order_detail())
print("=========================")
order2 = UberEats ("Siam", "01719659xxx", "Uttara")
print("=========================")
order2.add_items("Pineapple", "Dairy Milk", 80, 70)
print("=========================")
print(order2.print_order_detail())
# Out:
# Shakib welcome to uber eats
# ...
# user details:Shakib,Phone:01719658xxx,Adress:Mohakhali
# orders:{'Burger': 220, 'Coca Cola': 50}
# Total paid:270
# ...
# Siam welcome to uber eats
# ...
# user details:Siam,Phone:01719659xxx,Adress:Uttara
# orders:{'Pineapple': 80, 'Dairy Milk': 70}
# Total paid:150

# %%
#6
class Customer:
  def __init__(self,name):
    self.name=name

  def greet(self,name=None):
    if name != None:
      print(f'Hello!{name}')
    else:
      print('Hello')
  def purchase(self,*items):
      x=len(items)
      print((f"{self.name}, you purchased {x} items(s):"))
      for i in items:
        print(i)
customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")

print("-----------------------------")

customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello
# Sam, you purchased 3 items(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello!David
# David, you purchased 1 items(s):
# orange juice

# %%
#6
class Customer:
      def __init__(self, name):
        self.name = name

      def greet(self, name=None):
        if name != None:
            print(f"Hello {name}!")
        else:
            print("Hello!")

      def purchase(self, *item):
        print(f"{self.name}, you purchased {len(item)} items(s):")
        for i in item:
            print(i)
customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchased 3 items(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David, you purchased 1 items(s):
# orange juice

# %%
#7
class Cat:
  def __init__(self,*args):

    if len(args)==0:
      self.color='white'
      self.action='sitting'
    elif len(args)==1:
       self.color=args[0]
       self.action='sitting'
    elif len(args)==2:
      self.color=args[0]
      self.action=args[1]

  def printCat(self):
     print(f'{self.color} cat is {self.action}')

  def changeColor(self,color):
     self.color=color
c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# white cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
class Cat:
    def __init__(self, color="White", activity="sitting"):
        self.color = color
        self.activity = activity

    def printCat(self):
        print(f"{self.color} cat is {self.activity}")

    def changeColor(self, new_color):
        self.color = new_color
c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#8

class Student:

  def __init__(self,*args):
    if len(args)==2:
      self.name=args[0]
      self.id=args[1]
      self.d='cse'
    else:
      self.name=args[0]
      self.id=args[1]
      self.d=args[2]

  def dailyEffort(self,hour):
    self.hour=hour

  def printDetails(self):
      print(f'name:{self.name}\nID:{self.id}\nDepartment:{self.d}')

      if self.hour <= 2:
         print(f'daily effort:{self.hour} hour(s)')
         print('Suggestion: Should give more effort!')
      elif self.hour <= 4:
         print(f'daily effort:{self.hour} hour(s)')
         print('Suggestion: Keep up the good work!')
      else:
          print(f'daily effort:{self.hour} hour(s)')
          print('Suggestion: Excellent! Now motivate others.')

harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# name:Harry Potter
# ID:123
# Department:cse
# daily effort:3 hour(s)
# Suggestion: Keep up the good work!
# ...
# name:John Wick
# ID:456
# Department:BBA
# daily effort:2 hour(s)
# Suggestion: Should give more effort!
# ...
# name:Naruto Uzumaki
# ID:777
# Department:Ninja
# daily effort:6 hour(s)
# Suggestion: Excellent! Now motivate others.

# %%
class Student:
    def __init__(self, name, ID, dept="CSE"):
        self.name = name
        self.ID = ID
        self.dept = dept

    def dailyEffort(self, hours):
        self.hours = hours

    def printDetails(self):
        print(f"Name: {self.name}")
        print(f"ID: {self.ID}")
        print(f"Department: {self.dept}")
        print(f"Daily Effort: {self.hours} hour(s)")

        if self.hours <= 2:
            print("Suggestion: Should give more effort!")
        elif self.hours <= 4:
            print("Suggestion: Keep up the good work!")
        else:
            print("Suggestion: Execellent! Now motivate others.")


harry = Student("Harry Potter", 123)
harry.dailyEffort(3)
harry.printDetails()
print("========================")
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print("========================")
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Execellent! Now motivate others.

# %%
#9
class Batsman:
   def __init__(self,*args):
     if len(args) == 2:
       self.name='New Batsman'
       self.run=6101
       self.ball_f=7380
     else:
       self.name=args[0]
       self.run=args[1]
       self.ball_f=args[2]

   def printCareerStatistics(self):
       #print(self.name,self.run,self.ball_f)
       print(f'Name:{self.name}\nRuns scored:{self.run} , Balls Faced:{self.ball_f}')

   def battingStrikeRate(self):
       s=(self.run/self.ball_f*100)
       return s

   def setName(self,name):
       self.name=name

b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name:New Batsman
# Runs scored:6101 , Balls Faced:7380
# ...
# Name:Liton Das
# Runs scored:678 , Balls Faced:773
# ----------------------------
# 87.71021992238033
# ...
# Name:Shakib Al Hasan
# Runs scored:6101 , Balls Faced:7380
# ----------------------------
# 82.66937669376694

# %%
#10

class Author:
    def __init__(self, name=None, *books):
        self.name = name
        if name == None:
            self.name = "Default"

        booklist = ""
        if len(books) > 0:
            for i in books:
                booklist += i + "\n"
            self.books = booklist

    def changeName(self, new_name):
        self.name = new_name

    def addBooks(self, *books):
        booklist = ""
        for i in books:
            booklist += i + "\n"

        self.books = booklist

    def printDetails(self):
        print(f"Author Name: {self.name}")
        print("------------")
        print(f"List of Books:")
        print(self.books)
auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# ------------
# List of Books:
# Deyal
# Megher Opor Bari
#
# ...
# Default
# ...
# Author Name: Mario Puzo
# ------------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
#
# ...
# Author Name: Paolo Coelho
# ------------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#11
class TaxiLagbe:
  def __init__(self,t_num,area):
    self.t_num=t_num
    self.area=area
    self.l=[]
    self.total=0
    self.count=0

  def addPassenger(self,*arg):

     for i in arg:
       self.name,self.fare=i.split('_')
       fare=int(self.fare)
       self.total+=fare
       self.count+=1
       self.l.append(self.name)
       print(f'Dear {self.name}! Welcome to TaxiLagbe.')
  def printDetails(self):
   if self.count<=4:
     print(f'Trip info for Taxi number:{self.t_num}')
     print(f'This taxi can cover only {self.area} area.')
     print(f'Total passengers:{self.count}')
     print('Passenger lists:')
     print(','.join(self.l))
     print(f'Total collected fare: {self.fare} Taka')
   else:
     print('Taxi Full! No more passengers can be added.')
taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200')
taxi1.addPassenger('Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115')
taxi2.addPassenger('Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number:1010-01
# This taxi can cover only Dhaka area.
# Total passengers:4
# Passenger lists:
# Walker,Wood,Matt,Wilson
# Total collected fare: 105 Taka
# -------------------------------
# Dear Karen! Welcome to TaxiLagbe.
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number:1010-02
# This taxi can cover only Khulna area.
# Total passengers:2
# Passenger lists:
# Ronald,Parker
# Total collected fare: 215 Taka

# %%
#Task11

class TaxiLagbe:

  def __init__(self, t_num, area):
    self.taxi_number = t_num
    self.area = area
    self.passengerL = []
    self.fare = 0

  def addPassenger(self, *name_fare):
    list1 = []
    for iter1 in name_fare:
      if len(self.passengerL) < 4:
        list1 = iter1.split("_")
        self.passengerL.append(list1[0])
        self.fare += int(list1[1])
        print(f"Dear {list1[0]}! Welcome to TaxiLagbe.")
      else:
        print("Taxi Full! No more passengers can be added.")
        break

  def printDetails(self):
    print(f'''Trip info for Taxi number: {self.taxi_number}
This taxi can cover only {self.area} area.
Total passengers: {len(self.passengerL)}
Passenger lists:''')
    pL_string = ""
    for iter2 in self.passengerL:
      pL_string += iter2 + ", "
    print(f'''{pL_string[:-2]}
Total collected fare: {self.fare} Taka''')

taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200')
taxi1.addPassenger('Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115')
taxi2.addPassenger('Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker! Welcome to TaxiLagbe.
# Dear Wood! Welcome to TaxiLagbe.
# Dear Matt! Welcome to TaxiLagbe.
# Dear Wilson! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker, Wood, Matt, Wilson
# Total collected fare: 505 Taka
# -------------------------------
# Dear Ronald! Welcome to TaxiLagbe.
# Dear Parker! Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald, Parker
# Total collected fare: 330 Taka

# %%
#12
class Account:
    def __init__(self, name=None, balance=None):
        self.name = name
        self.balance = balance

        if self.name == None:
            self.name = "Default Account"

        if self.balance == None:
            self.balance = 0.0

    def withdraw(self, amount):
        var = self.balance - amount
        if var <= 3070.0:
            print(
                "Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum."
            )
        else:
            print(f"Withdraw successful! New balance is: {var}")

    def details(self):
        return f"{self.name}\n{self.balance:.1f}"
a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930)
print("------------------------")
a2.withdraw(600)
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400.0
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is: 3071.0

# %%
#13

class StudentDatabase:

  def __init__(self, name, id):
    self.name = name
    self.id = id
    self.grades = {}

  def calculateGPA(self, cour_gr_L, sem):
    course_grade = []
    courseL = []
    gradeL = []
    dict1 = {}
    gp_cred = 0
    for iter1 in cour_gr_L:
      #(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
      course_grade = iter1.split(": ")
      courseL.append(course_grade[0])
      gradeL.append(float(course_grade[1]))
    for iter2 in gradeL:
      gp_cred += (iter2 * 3)
    avgP = gp_cred / (3*len(gradeL)) #avgP = "%.2f"%avgP
    dict1[tuple(courseL)] = float("{0:.2f}".format(avgP))
    self.grades[sem] = dict1

  def printDetails(self):
    print("Name:", self.name)
    print("ID:", self.id)
    # {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
    for key1, val1 in self.grades.items():
      print(f"Courses taken in {key1}:")
      for key2, val2 in val1.items():
        for iter3 in key2:
          print(iter3)
        print("GPA:", val2)

s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('------------------------------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
print('------------------------------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('------------------------------------------------------')
s2.printDetails()
# Out:
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ------------------------------------------------------
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020:
# CSE230
# CSE220
# MAT110
# GPA: 4.0
# Courses taken in Summer2021:
# CSE250
# CSE330
# GPA: 3.85
# ------------------------------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8}}
# ------------------------------------------------------
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022:
# CSE111
# CSE260
# ENG101
# GPA: 3.8

# %%
#14
class Test3:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):
        x, y = 2, 3
        msg = [0]
        msg[0] = 3
        y = self.y + msg[0]
        self.methodB(msg, msg[0])
        x = self.y + msg[0]
        self.sum = x + y + msg[0]
        print(x, y, self.sum)
    def methodB(self, mg2, mg1):
        x = 0
        self.y = self.y + mg2[0]
        x = x + 33 + mg1
        self.sum = self.sum + x + self.y
        mg2[0] = self.y + mg1
        mg1 = mg1 + x + 2
        print(x, self.y, self.sum)

t3 = Test3()
t3.methodA()
t3.methodA()
t3.methodA()
t3.methodA()
# Out:
# 36 3 39
# 9 3 18
# 36 6 60
# 15 6 30
# 36 9 75
# 21 9 42
# 36 12 90
# 27 12 54

# %%
#15
class Test5:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):
        x = 0
        z = 0
        while (z < 5):
            self.y = self.y + self.sum
            x = self.y + 1
            print(x, self.y, self.sum)
            self.sum = self.sum + self.methodB(x, self.y)
            z += 1
    def methodB(self, m, n):
        x = 0
        sum = 0
        self.y = self.y + m
        x = n - 4
        sum = sum + self.y
        print(x, self.y, sum)
        return self.sum

t5 = Test5()
t5.methodA()
# Out:
# 1 0 0
# -4 1 1
# 2 1 0
# -3 3 3
# 4 3 0
# -1 7 7
# 8 7 0
# 3 15 15
# 16 15 0
# 11 31 31

# %%
#16
class FinalT6A:
    def __init__(self, x, p):
        self.temp, self.sum, self.y = 4, 0, 1
        self.temp += 1
        self.y = self.temp - p
        self.sum = self.temp + x
        print(x, self.y, self.sum)
    def methodA(self):
        x = 0
        y = 0
        y = y + self.y
        x = self.y + 2 + self.temp
        self.sum = x + y + self.methodB(self.temp, y)
        print(x, y, self.sum)
    def methodB(self, temp, n):
        x = 0
        temp += 1
        self.y = self.y + temp
        x = x + 3 + n
        self.sum = self.sum + x + self.y
        print(x, self.y, self.sum)
        return self.sum

q1 = FinalT6A(2,1)
q1.methodA()
q1.methodA()
# Out:
# 2 4 7
# 7 10 24
# 11 4 39
# 13 16 68
# 17 10 95

# %%
#17
class Test5:
  def __init__(self):
      self.sum = 0
      self.y = 0
  def methodA(self):
      x=y=k=0
      msg = [5]
      while (k < 2):
          y += msg[0]
          x = y + self.methodB(msg, k)
          self.sum = x + y + msg[0]
          print(x ," " , y, " " , self.sum)
          k+=1
  def methodB(self, mg2, mg1):
        x = 0
        self.y += mg2[0]
        x = x + 3 + mg1
        self.sum += x + self.y
        mg2[0] = self.y + mg1
        mg1 += x + 2
        print(x , " " ,self.y, " " , self.sum)
        return mg1

t1 = Test5()
t1.methodA()
t1.methodA()
t1.methodA()
# Out:
# 3   5   8
# 10   5   20
# 4   10   34
# 17   10   38
# 3   15   56
# 10   5   30
# 4   30   64
# 27   20   78
# 3   35   116
# 10   5   50
# 4   70   124
# 47   40   158

# %%
#18
class Test4:
    def __init__(self):
        self.sum, self.y = 0, 0
    def methodA(self):
        x, y = 0, 0
        msg = [0]
        msg[0] = 5
        y = y + self.methodB(msg[0])
        x = y + self.methodB(msg, msg[0])
        self.sum = x + y + msg[0]
        print(x, y, self.sum)
    def methodB(self, *args):
        if len(args) == 1:
            mg1 = args[0]
            x, y = 0, 0
            y = y + mg1
            x = x + 33 + mg1
            self.sum = self.sum + x + y
            self.y = mg1 + x + 2
            print(x, y, self.sum)
            return y
        else:
            mg2, mg1 = args
            x = 0
            self.y = self.y + mg2[0]
            x = x + 33 + mg1
            self.sum = self.sum + x + self.y
            mg2[0] = self.y + mg1
            mg1 = mg1 + x + 2
            print(x, self.y, self.sum)
            return self.sum

t3 = Test4()
t3.methodA()
t3.methodA()
t3.methodA()
t3.methodA()
# Out:
# 38 5 43
# 38 50 131
# 136 5 196
# 38 5 239
# 38 50 327
# 332 5 392
# 38 5 435
# 38 50 523
# 528 5 588
# 38 5 631
# 38 50 719
# 724 5 784

# %%
#19
class msgClass:
    def __init__(self):
        self.content = 0
class Q5:
    def __init__(self):
        self.sum = 1
        self.x = 2
        self.y = 3
    def methodA(self):
        x, y = 1, 1
        msg = []
        myMsg = msgClass()
        myMsg.content = self.x
        msg.append(myMsg)
        msg[0].content = self.y + myMsg.content
        self.y = self.y + self.methodB(msg[0])
        y = self.methodB(msg[0]) + self.y
        x = y + self.methodB(msg[0], msg)
        self.sum = x + y + msg[0].content
        print(x," ", y," ", self.sum)
    def methodB(self, mg1, mg2 = None):
        if mg2 == None:
            x, y = 5, 6
            y = self.sum + mg1.content
            self.y = y + mg1.content
            x = self.x + 7 +mg1.content
            self.sum = self.sum + x + y
            self.x = mg1.content + x +8
            print(x, " ", y," ", self.sum)
            return y
        else:
            x = 1
            self.y += mg2[0].content
            mg2[0].content = self.y + mg1.content
            x = x + 4 + mg1.content
            self.sum += x + self.y
            mg1.content = self.sum - mg2[0].content
            print(self.x, " ",self.y," ", self.sum)
            return self.sum

q = Q5()
q.methodA()
# Out:
# 14   6   21
# 39   26   86
# 52   36   168
# 225   57   409

# %%
class Team:
   def __init__(self,country_name,win,language=''):
     self.country_name=country_name
     self.win=win
     self.player_list=''
   def calculateCost(self):
     pass
   def printDetails(self):
     pass
   def addplayer(self,player_obj):
     self.player_obj=player_obj

class Player:
  def __init__(self,player_name,player_position=None):
      self.player_name=player_name
      self.player_position=player_position

argentina=Team('argentina',2)
print('1===================================')
print(argentina.player_list)
print('2====================================')
argentina.calculateCost()
print('3====================================')
argentina.printDetails()
print('4=======================================')
messi=player('messi')
maria=player('maria')
marcos=player('marcos','defender')
argentina.addplayer(messi)
argentina.addplayer(maria)
argentina.addplayer(marcos)
# Out:
# 1===================================
#
# 2====================================
# 3====================================
# 4=======================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-fb8e81658d6f> in <module>
#      24 argentina.printDetails()
#      25 print('4=======================================')
# ---> 26 messi=player('messi')
#      27 maria=player('maria')
#      28 marcos=player('marcos','defender')
#
# NameError: name 'player' is not defined

# %%
#20
class Student:
  def __init__(self,*args):
    if len(args) == 0:
      print('Student name and department need to be set')
    elif len(args)==1:
      print(f'Department for {args[0]} needs to be set')
    else:
      print(f'{args[0]} is from {args[1]} department')

  def update_name(self,name):
     self.name=name

  def update_department(self,d):
    self.d=d

  def enroll(self,*arg):
    if len(arg) == 1:
      return f'{self.name} enrolled in {len(arg)} courses:'
      return arg[0]
    elif len(arg) == 2:
      return f'{self.name} enrolled in {len(arg)} courses:'
      return arg[0],arg[1]
    else:
      return f'{self.name} enrolled in {len(arg)} courses:'
      return arg[0],arg[1],arg[2]

  def printDetail(self):
    print(f'Name:{self.name}')
    print(f'Department:{self.d}')
    #print(f'')

s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-1a5757fe1576> in <module>
#      41 s2.update_department("BBA")
#      42 s1.enroll("CSE110", "MAT110", "ENG091")
# ---> 43 s2.enroll("BUS101")
#      44 s3.enroll("MAT110", "PHY111")
#      45 print("###########################")
#
# <ipython-input-1-1a5757fe1576> in enroll(self, *arg)
#      17   def enroll(self,*arg):
#      18     if len(arg) == 1:
# ---> 19       return f'{self.name} enrolled in {len(arg)} courses:'
#      20       return arg[0]
#      21     elif len(arg) == 2:
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
#20
class Student:

  def __init__(self, name = None, dept = None):
    self.name = name
    self.department = dept
    if name == None and dept == None:
      print("Student name and department need to be set")
    elif dept == None:
      print(f"Department for {self.name} needs to be set")
    else:
      print(f"{self.name} is from {self.department} department")

  def update_name(self, new_name):
    self.name = new_name

  def update_department(self, new_dept):
    self.department = new_dept

  def enroll(self, *args):
    self.course = args

  def printDetail(self):
    print(f'''Name: {self.name}
Department: {self.department}
{self.name} enrolled in {len(self.course)} course(s):''')
    courses = ""
    for iter1 in self.course:
      courses += iter1 + ", "
    print(courses[:-2])
s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set
# ...
# Jon is from EEE department
# ...
# ###########################
# Name: Bob
# Department: CSE
# Bob enrolled in 3 course(s):
# CSE110, MAT110, ENG091
# ...
# Name: Carol
# Department: BBA
# Carol enrolled in 1 course(s):
# BUS101
# ...
# Name: Jon
# Department: EEE
# Jon enrolled in 2 course(s):
# MAT110, PHY111

# %%
class Author:
  def __init__(self,*args):
    if len(args) == 0:
      print('A book can not be added without author name')
    else:
      self.name=args[0]

  def addBook(self,bname):

  def printDetail(self):



a1 = Author()
print("=================================")
a1.addBook(“Ice”, “Science Fiction”)
print("=================================")
a1.setName(“Anna Kavan”)
a1.addBook(“Ice”, “Science Fiction”)
a1.printDetail()
print("=================================")
a2 = Author(“Humayun Ahmed”)
a2.addBook(“Onnobhubon”, “Science Fiction”)
a2.addBook(“Megher Upor Bari”, “Horror”)
print("=================================")
a2.printDetail()
a2.addBook(“Ireena”, “Science Fiction”)
print("=================================")
a2.printDetail()
print("=================================")

# %%
#Task21

class Student:

  def __init__(self, name, id, dept):
    self.name = name
    self.id = id
    self.department = dept

  def details(self):
    return f'''Name: {self.name}
ID: {self.id}
Department: {self.department}'''

  def advise(self, *args):
    print(f"Alice, you have taken {len(args)*3.0} credits.")
    course = ""
    for iter in args:
      course += iter + ", "
    print("List of courses:", course[:-2])
    if len(args) < 3:
      print(f"Status: You have to take at least {3-len(args)} more course.")
    elif len(args) > 4:
      print(f"Status: You have to drop at least {len(args)-4} course.")
    else:
      print("Status: Ok")

s1 = Student('Alice','20103012','CSE')
s2 = Student('Bob', '18301254','EEE')
s3 = Student('Carol', '17101238','CSE')
print('##########################')
print(s1.details())
print('##########################')
print(s2.details())
print('##########################')
s1.advise('CSE110', 'MAT110', 'PHY111')
print('##########################')
s2.advise('BUS101', 'MAT120')
print('##########################')
s3.advise('MAT110', 'PHY111', 'ENG102',
'CSE111', 'CSE230')
# Out:
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# ##########################
# Alice, you have taken 9.0 credits.
# List of courses: CSE110, MAT110, PHY111
# Status: Ok
# ##########################
# Alice, you have taken 6.0 credits.
# List of courses: BUS101, MAT120
# Status: You have to take at least 1 more course.
# ##########################
# Alice, you have taken 15.0 credits.
# List of courses: MAT110, PHY111, ENG102, CSE111, CSE230
# Status: You have to drop at least 1 course.

# %%
#Task22

class Hotel:

  def __init__(self, h_name):
    self.hotel = h_name
    self.staff_id = 0
    self.guest_id = 0
    self.staff = {}
    self.guest = {}

  def addStuff(self, name1, age1, phone1 = "000"):
    self.staff_id += 1
    print(f"Staff With ID {self.staff_id} is added")
    self.staff[self.staff_id] = [name1, age1, phone1]

  def getStuffById(self, idS):
    return f'''Staff ID: {idS}
Name: {self.staff[idS][0]}
Age: {self.staff[idS][1]}
Phone no.: {self.staff[idS][2]}'''

  def addGuest(self, name2, age2, phone2):
    self.guest_id += 1
    print(f"Guest With ID {self.guest_id} is created")
    self.guest[self.guest_id] = [name2, age2, phone2]

  def getGuestById(self, idG):
    return f'''Guest ID: {idG}
Name: {self.guest[idG][0]}
Age: {self.guest[idG][1]}
Phone no.: {self.guest[idG][2]}'''

  def allStaffs(self):
    print(f'''All Staffs:
Number of Staff: {self.staff_id}''')
    for key1, value1 in self.staff.items():
      print(f"Staff ID: {key1} Name: {value1[0]} Age: {value1[1]} Phone no: {value1[2]}")

  def allGuest(self):
    print(f'''All Guest:
Number of Guest: {self.guest_id}''')
    for key2, value2 in self.guest.items():
      print(f"Guest ID: {key2} Name: {value2[0]} Age: {value2[1]} Phone no.: {value2[2]}")
h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol",35,'123')
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, '431')
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# Staff With ID 1 is added
# ...
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.: 000
# ...
# Guest With ID 1 is created
# ...
# Guest ID: 1
# Name: Carol
# Age: 35
# Phone no.: 123
# ...
# Guest With ID 2 is created
# ...
# Guest ID: 2
# Name: Diana
# Age: 32
# Phone no.: 431
# ...
# All Staffs:
# Number of Staff: 1
# Staff ID: 1 Name: Adam Age: 26 Phone no: 000
# ...
# All Guest:
# Number of Guest: 2
# Guest ID: 1 Name: Carol Age: 35 Phone no.: 123
# Guest ID: 2 Name: Diana Age: 32 Phone no.: 431

# %%
#Task 23

class Author:

  def __init__(self, a_name1 = None):
    self.name = a_name1
    self.book_dict = {}
    self.book_num = 0

  def addBook(self, b_name, genre):
    if self.name == None:
      print("A book can not be added without author name")
    else:
      self.book_num += 1
      if genre not in self.book_dict:
        self.bookL = [b_name]
        self.book_dict[genre] = self.bookL
      else:
        self.bookL = self.book_dict[genre]
        self.bookL.append(b_name)
        self.book_dict[genre] = self.bookL

  def setName(self, a_name2):
    self.name = a_name2

  def printDetail(self):
    print(f'''Number of Book(s): {self.book_num}
Author Name: {self.name}''')
    books = ""
    for key, value in self.book_dict.items():
      print(key, end = ": ")
      for iter in value:
        books += iter + ", "
      print(books[:-2])
      books = ""
a1 = Author()
print("=================================")
a1.addBook('Ice', 'Science Fiction')
print("=================================")
a1.setName('Anna Kavan')
a1.addBook('Ice', 'Science Fiction')
a1.printDetail()
print("=================================")
a2 = Author('Humayun Ahmed')
a2.addBook('Onnobhubon', 'Science Fiction')
a2.addBook('Megher Upor Bari', 'Horror')
print("=================================")
a2.printDetail()
a2.addBook('Ireena', 'Science Fiction')
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book can not be added without author name
# ...
# Number of Book(s): 1
# Author Name: Anna Kavan
# Science Fiction: Ice
# ...
# Number of Book(s): 2
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon
# Horror: Megher Upor Bari
# ...
# Number of Book(s): 3
# Author Name: Humayun Ahmed
# Science Fiction: Onnobhubon, Ireena
# Horror: Megher Upor Bari
# ...

# %%
#24
class Hospital:

  def __init__(self, h_name):
    self.hospital = h_name
    self.dictD = {}
    self.dictP = {}

  def addDoctor(self, doc):
    self.dictD[doc.idD] = [doc.doctor, doc.speciality]

  def getDoctorByID(self, id):
    return f'''Doctor's ID: {id}
Name: {self.dictD[id][0]}
Speciality: {self.dictD[id][1]}'''

  def addPatient(self, pat):
    self.dictP[pat.idP] = [pat.patient, pat.age, pat.phone]

  def getPatientByID(self, id):
    return f'''Patient's ID: {id}
Name: {self.dictP[id][0]}
Age: {self.dictP[id][1]}
Phone no.: {self.dictP[id][2]}'''

  def allDoctors(self):
    print(f'''All Doctors:
Number of Doctors: {len(self.dictD)}
{self.dictD}''')

  def allPatients(self):
    print(f'''All Patients:
Number of Patients: {len(self.dictP)}
{self.dictP}''')


class Doctor:

  def __init__(self, idD, des, d_name, spec):
    self.idD = idD
    self.designation = des
    self.doctor = d_name
    self.speciality = spec


class Patient:

  def __init__(self, idP, des, p_name, age, phone):
    self.idP = idP
    self.designation = des
    self.patient = p_name
    self.age = age
    self.phone = phone

h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
h.allDoctors()
h.allPatients()
# Out:
# ...
# Doctor's ID: 1d
# Name: Samar Kumar
# Speciality: Neurologist
# ...
# Patient's ID: 1p
# Name: Kashem Ahmed
# Age: 35
# Phone no.: 12345
# ...
# Patient's ID: 2p
# Name: Tanina Haque
# Age: 26
# Phone no.: 33456
# ...
# All Doctors:
# Number of Doctors: 1
# {'1d': ['Samar Kumar', 'Neurologist']}
# All Patients:
# Number of Patients: 2
# {'1p': ['Kashem Ahmed', 35, 12345], '2p': ['Tanina Haque', 26, 33456]}

# %%
#25
class Vaccine:
  def __init__(self,name,md_in,intrvl):
    self.name=name
    self.md_in=md_in
    self.intrvl=intrvl
#=============================================
class Person:
  def __init__(self,pname,age,ptype='General Citizen'):
    self.pname=pname
    self.age=age
    self.ptype=ptype
    self.vac=''
    self.firstdose=False
    self.secdose=False

  def pushVaccine(self,vacN,dose='1st dose'):

    if dose == '1st dose':
      if self.age >=25 or self.ptype=='Student':
        self.vac=vacN   #storing obj of vac / memory location
        self.firstdose=True
        print('1st dose done',self.pname)
      else:
        print('Sorry',self.pname,' Minimum age for taking vaccines is 25 years now.')

    else:
      if self.vac.name != vacN.name:
        print("Sorry",self.pname,'you can’t take 2 different vaccines')
      elif self.firstdose == True:
        self.secdose= True
        print('2nd dose done for',self.pname)

  def showDetail(self):
     print("Name:",self.pname,"Age:",self.age,"Type:",self.ptype)
     print("Vaccine Name:", self.vac.name)

     if self.secdose == True:
       print('1st dose done')
       print('2nd dose done')
     elif self.firstdose == True:
       print('1st dose given')
       print("2nd dose:Please come after ",self.vac.intrvl,'days')


astra = Vaccine("AstraZeneca", "UK", 60)
modr = Vaccine("Moderna", "UK", 30)
sin = Vaccine("Sinopharm", "China", 30)
p1 = Person("Bob", 21, "Student")
print("=================================")
p1.pushVaccine(astra)
print("=================================")
p1.showDetail()
print("=================================")
p1.pushVaccine(sin, "2nd Dose")
print("=================================")
p1.pushVaccine(astra, "2nd Dose")
print("=================================")
p1.showDetail()
print("=================================")
p2 = Person("Carol", 23, "Actor")
print("=================================")
p2.pushVaccine(sin)
print("=================================")
p3 = Person("David", 34)
print("=================================")
p3.pushVaccine(modr)
print("=================================")
p3.showDetail()
print("=================================")
p3.pushVaccine(modr, "2nd Dose")
